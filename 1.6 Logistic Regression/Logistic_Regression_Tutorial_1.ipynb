# %% [markdown]
# **Import Dependencies**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('https://github.com/codebasics/py/raw/801ee0ee4d342fd22b89915dc0c4864250a0ec10/ML/7_logistic_reg/insurance_data.csv#L4')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.shape
# Out:
# (27, 2)

# %% [markdown]
# **Data Visualization**

# %%
plt.scatter(df['age'], df['bought_insurance'], color='red');

# %%
X= df[['age']]
y= df['bought_insurance']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,train_size=0.9, random_state=10)

# %%
X_test
# Out:
#     age
# 7    60
# 5    56
# 18   19

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.06470723, 0.93529277],
#        [0.10327405, 0.89672595],
#        [0.92775095, 0.07224905]])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict([[25]])
# Out:
# array([0])
